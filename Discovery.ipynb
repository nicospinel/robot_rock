# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 2.1 MB/s eta 0:00:01
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id='572fe7cf75b545aaa2ec3c3ad360d5b1',
                                                           client_secret='b270193c1d9b43b0a40ce1a67c9edb22')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
daft_uri = 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'

# %%
results = sp.artist_albums(daft_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Random Access Memories
# Daft Punk | Random Access Memories | The Collaborators
# TRON: Legacy Reconfigured
# TRON: Legacy Reconfigured (Australian Version)
# TRON: Legacy
# TRON: Legacy (Original Soundtrack)
# TRON: Legacy
# TRON: Legacy
# TRON: Legacy
# TRON: Legacy
# TRON: Legacy
# TRON: Legacy
# TRON: Legacy
# TRON: Legacy (Original Motion Picture Soundtrack/Japan Release Version)
# TRON: Legacy
# TRON: Legacy - The Complete Edition (Original Motion Picture Soundtrack)
# Alive 2007
# Alive 2007
# Alive 2007
# Alive 2007
# Alive 2007
# Human After All (Remixes)
# Human After All (Remixes)
# Human After All
# Human After All
# Daft Club
# Alive 1997
# Discovery
# Homework

# %%
for s,album in enumerate(albums):
    print(s, album['name'])
# Out:
# 0 Random Access Memories
# 1 Daft Punk | Random Access Memories | The Collaborators
# 2 TRON: Legacy Reconfigured
# 3 TRON: Legacy Reconfigured (Australian Version)
# 4 TRON: Legacy
# 5 TRON: Legacy (Original Soundtrack)
# 6 TRON: Legacy
# 7 TRON: Legacy
# 8 TRON: Legacy
# 9 TRON: Legacy
# 10 TRON: Legacy
# 11 TRON: Legacy
# 12 TRON: Legacy
# 13 TRON: Legacy (Original Motion Picture Soundtrack/Japan Release Version)
# 14 TRON: Legacy
# 15 TRON: Legacy - The Complete Edition (Original Motion Picture Soundtrack)
# 16 Alive 2007
# 17 Alive 2007
# 18 Alive 2007
# 19 Alive 2007
# 20 Alive 2007
# 21 Human After All (Remixes)
# 22 Human After All (Remixes)
# 23 Human After All
# 24 Human After All
# 25 Daft Club
# 26 Alive 1997
# 27 Discovery
# 28 Homework

# %%
albums[27]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#    'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#    'id': '4tZwfgrHOc3mvqYlEYSvVi',
#    'name': 'Daft Punk',
#    'type': 'artist',
#    'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
# ...

# %%
res = sp.album_tracks(album_id = 'spotify:album:2noRn2Aes5aoNVsU6iWThc')
res
# Out:
# {'href': 'https://api.spotify.com/v1/albums/2noRn2Aes5aoNVsU6iWThc/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#      'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#      'id': '4tZwfgrHOc3mvqYlEYSvVi',
#      'name': 'Daft Punk',
#      'type': 'artist',
#      'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
# ...

# %%
sp.audio_features('spotify:track:5W3cjX2J3tjhG8zb6u0qHn')[0].keys()
# Out:
# [{'danceability': 0.817,
#   'energy': 0.716,
#   'key': 6,
#   'loudness': -8.898,
#   'mode': 0,
#   'speechiness': 0.144,
#   'acousticness': 0.0427,
#   'instrumentalness': 0.00263,
#   'liveness': 0.358,
#   'valence': 0.692,
#   'tempo': 123.475,
#   'type': 'audio_features',
#   'id': '5W3cjX2J3tjhG8zb6u0qHn',
#   'uri': 'spotify:track:5W3cjX2J3tjhG8zb6u0qHn',
#   'track_href': 'https://api.spotify.com/v1/tracks/5W3cjX2J3tjhG8zb6u0qHn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5W3cjX2J3tjhG8zb6u0qHn',
#   'duration_ms': 224693,
#   'time_signature': 4}]

# %%
sp.audio_features('spotify:track:5W3cjX2J3tjhG8zb6u0qHn')
# Out:
# [{'danceability': 0.817,
#   'energy': 0.716,
#   'key': 6,
#   'loudness': -8.898,
#   'mode': 0,
#   'speechiness': 0.144,
#   'acousticness': 0.0427,
#   'instrumentalness': 0.00263,
#   'liveness': 0.358,
#   'valence': 0.692,
#   'tempo': 123.475,
#   'type': 'audio_features',
#   'id': '5W3cjX2J3tjhG8zb6u0qHn',
#   'uri': 'spotify:track:5W3cjX2J3tjhG8zb6u0qHn',
#   'track_href': 'https://api.spotify.com/v1/tracks/5W3cjX2J3tjhG8zb6u0qHn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5W3cjX2J3tjhG8zb6u0qHn',
#   'duration_ms': 224693,
#   'time_signature': 4}]

# %%
sp.audio_analysis('spotify:track:5W3cjX2J3tjhG8zb6u0qHn')
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1501045834,
#   'analysis_time': 7.42576,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 4954488,
#   'duration': 224.69333,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.77823,
#   'start_of_fade_out': 219.48082,
#   'loudness': -8.898,
#   'tempo': 123.475,
#   'tempo_confidence': 0.841,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'key': 6,
#   'key_confidence': 0.356,
#   'mode': 0,
#   'mode_confidence': 0.466,
# ...

# %%
results = sp.search(q='taylor', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Love Story (Taylor’s Version)
# 1 willow
# 2 champagne problems
# 3 cardigan
# 4 exile (feat. Bon Iver)
# 5 gold rush
# 6 the 1
# 7 no body, no crime (feat. HAIM)
# 8 You Need To Calm Down
# 9 ‘tis the damn season
# 10 Taylor
# 11 Gasoline (feat. Taylor Swift)
# 12 tolerate it
# 13 willow
# 14 Blank Space
# 15 Lover
# 16 Love Story
# 17 ivy
# 18 The Man
# 19 You Belong With Me
